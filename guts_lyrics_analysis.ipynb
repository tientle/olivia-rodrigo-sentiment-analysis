# %%
# Based on codecademy's analysis of Taylor Swift lyrics: https://6bfaae8daaad4b52926b136460c4501e.cc-propeller.cloud/files/solution.html

# Import libraries
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer
import collections

# %%
# Read in lyrics dataset
lyrics = pd.read_csv("./lyrics.csv")
lyrics
# Out:
#                             title  \
# 0              all-american bitch
# 1                 bad idea right?
# 2                         vampire
# 3                            lacy
# 4   ballad of a homeschooled girl
# 5                  making the bed
# 6                         logical
# 7                    get him back
# 8             love is embarassing
# 9                      the grudge
# 10            pretty isn’t pretty
# 11                  teenage dream
#
#                                                lyrics
# 0   I am light as a feather, I'm as stiff as a boa...
# 1   Hey\nHaven't heard from you in a couple of mon...
# 2   Hate to give the satisfaction asking how you'r...
# 3   Lacy, oh Lacy, skin like puff pastry\nAren't y...
# 4   Cat got my tongue\nAnd I don't think I get alo...
# 5   Want it, so I got it, did it, so it's done\nAn...
# 6   Master manipulator\nGod, you're so good at wha...
# 7   One, two, three\nWait, is this the song with t...
# 8   I told my friends you were the one\nAfter I'd ...
# 9   I have nightmares each week about that Friday ...
# 10  Bought a bunch of makeup\nTryna' cover up my f...
# 11  When am I gonna stop being wise beyond my year...

# %%
# Lowercase lyrics, remove newline breaks (\n)

# Create a new column clean_lyrics. Lowercase the lyrics.
lyrics['clean_lyrics'] = lyrics['lyrics'].str.lower()
lyrics

# Remove punctuation
lyrics['clean_lyrics']= lyrics['clean_lyrics'].str.replace('[^\w\s]','')
lyrics
# Out:
#                             title  \
# 0              all-american bitch
# 1                 bad idea right?
# 2                         vampire
# 3                            lacy
# 4   ballad of a homeschooled girl
# 5                  making the bed
# 6                         logical
# 7                    get him back
# 8             love is embarassing
# 9                      the grudge
# 10            pretty isn’t pretty
# 11                  teenage dream
#
#                                                lyrics  \
# 0   I am light as a feather, I'm as stiff as a boa...
# 1   Hey\nHaven't heard from you in a couple of mon...
# 2   Hate to give the satisfaction asking how you'r...
# 3   Lacy, oh Lacy, skin like puff pastry\nAren't y...
# 4   Cat got my tongue\nAnd I don't think I get alo...
# 5   Want it, so I got it, did it, so it's done\nAn...
# 6   Master manipulator\nGod, you're so good at wha...
# 7   One, two, three\nWait, is this the song with t...
# 8   I told my friends you were the one\nAfter I'd ...
# 9   I have nightmares each week about that Friday ...
# 10  Bought a bunch of makeup\nTryna' cover up my f...
# 11  When am I gonna stop being wise beyond my year...
#
#                                          clean_lyrics
# 0   i am light as a feather im as stiff as a board...
# 1   hey\nhavent heard from you in a couple of mont...
# 2   hate to give the satisfaction asking how youre...
# 3   lacy oh lacy skin like puff pastry\narent you ...
# 4   cat got my tongue\nand i dont think i get alon...
# 5   want it so i got it did it so its done\nanothe...
# 6   master manipulator\ngod youre so good at what ...
# 7   one two three\nwait is this the song with the ...
# 8   i told my friends you were the one\nafter id k...
# 9   i have nightmares each week about that friday ...
# 10  bought a bunch of makeup\ntryna cover up my fa...
# 11  when am i gonna stop being wise beyond my year...

# %%
#run this cell to tokenize the words in the clean_lyric column
lyrics['lyrics_tok'] = lyrics['clean_lyrics'].apply(lambda x: word_tokenize(x))
lyrics
# Out:
#                             title  \
# 0              all-american bitch
# 1                 bad idea right?
# 2                         vampire
# 3                            lacy
# 4   ballad of a homeschooled girl
# 5                  making the bed
# 6                         logical
# 7                    get him back
# 8             love is embarassing
# 9                      the grudge
# 10            pretty isn’t pretty
# 11                  teenage dream
#
#                                                lyrics  \
# 0   I am light as a feather, I'm as stiff as a boa...
# 1   Hey\nHaven't heard from you in a couple of mon...
# 2   Hate to give the satisfaction asking how you'r...
# 3   Lacy, oh Lacy, skin like puff pastry\nAren't y...
# 4   Cat got my tongue\nAnd I don't think I get alo...
# 5   Want it, so I got it, did it, so it's done\nAn...
# 6   Master manipulator\nGod, you're so good at wha...
# 7   One, two, three\nWait, is this the song with t...
# 8   I told my friends you were the one\nAfter I'd ...
# 9   I have nightmares each week about that Friday ...
# 10  Bought a bunch of makeup\nTryna' cover up my f...
# 11  When am I gonna stop being wise beyond my year...
#
#                                          clean_lyrics  \
# 0   i am light as a feather im as stiff as a board...
# 1   hey\nhavent heard from you in a couple of mont...
# 2   hate to give the satisfaction asking how youre...
# 3   lacy oh lacy skin like puff pastry\narent you ...
# 4   cat got my tongue\nand i dont think i get alon...
# 5   want it so i got it did it so its done\nanothe...
# 6   master manipulator\ngod youre so good at what ...
# 7   one two three\nwait is this the song with the ...
# 8   i told my friends you were the one\nafter id k...
# 9   i have nightmares each week about that friday ...
# 10  bought a bunch of makeup\ntryna cover up my fa...
# 11  when am i gonna stop being wise beyond my year...
#
#                                            lyrics_tok
# 0   [i, am, light, as, a, feather, im, as, stiff, ...
# 1   [hey, havent, heard, from, you, in, a, couple,...
# 2   [hate, to, give, the, satisfaction, asking, ho...
# 3   [lacy, oh, lacy, skin, like, puff, pastry, are...
# 4   [cat, got, my, tongue, and, i, dont, think, i,...
# 5   [want, it, so, i, got, it, did, it, so, its, d...
# 6   [master, manipulator, god, youre, so, good, at...
# 7   [one, two, three, wait, is, this, the, song, w...
# 8   [i, told, my, friends, you, were, the, one, af...
# 9   [i, have, nightmares, each, week, about, that,...
# 10  [bought, a, bunch, of, makeup, tryna, cover, u...
# 11  [when, am, i, gon, na, stop, being, wise, beyo...

# %%
#determine what words overall are the most frequently used words
#create a list of all the words in the lyrics_tok column
word_list = [word for list_ in lyrics['lyrics_tok'] for word in list_]
word_list
# Out:
# ['i',
#  'am',
#  'light',
#  'as',
#  'a',
#  'feather',
#  'im',
#  'as',
#  'stiff',
#  'as',
#  'a',
#  'board',
#  'i',
#  'pay',
#  'attention',
#  'to',
#  'things',
#  'that',
#  'most',
#  'people',
#  'ignore',
#  'and',
#  'im',
#  'alright',
#  'with',
#  'the',
#  'movies',
#  'that',
#  'make',
#  'jokes',
#  'bout',
#  'senseless',
#  'cruelty',
#  'thats',
#  'for',
#  'sure',
#  'and',
#  'i',
#  'am',
#  'built',
#  'like',
#  'a',
#  'mother',
#  'and',
#  'a',
#  'total',
#  'machine',
#  'i',
#  'feel',
#  'for',
#  'your',
#  'every',
#  'little',
#  'issue',
#  'i',
#  'know',
#  'just',
#  'what',
#  'you',
#  'mean',
#  'and',
#  'i',
#  'make',
#  'light',
#  'of',
#  'the',
#  'darkness',
#  'ive',
#  'got',
#  'sun',
#  'in',
#  'my',
#  'motherfuckin',
#  'pocket',
#  'best',
#  'believe',
#  'yeah',
#  'you',
#  'know',
#  'me',
#  'i',
#  'forgive',
#  'and',
#  'i',
#  'forget',
#  'i',
#  'know',
#  'my',
#  'age',
#  'and',
#  'i',
#  'act',
#  'like',
#  'it',
#  'got',
#  'what',
#  'you',
#  'cant',
#  'resist',
#  'im',
#  'a',
#  'perfect',
#  'allamerican',
#  'i',
#  'am',
#  'light',
#  'as',
#  'a',
#  'feather',
#  'im',
#  'as',
#  'fresh',
#  'as',
#  'the',
#  'air',
#  'cocacola',
#  'bottles',
#  'that',
#  'i',
#  'only',
#  'use',
#  'to',
#  'curl',
#  'my',
#  'hair',
#  'i',
#  'got',
#  'class',
#  'and',
#  'integrity',
#  'just',
#  'like',
#  'a',
#  'goddamn',
#  'kennedy',
#  'i',
#  'swear',
#  'with',
#  'love',
#  'to',
#  'spare',
#  'i',
#  'forgive',
#  'and',
#  'i',
#  'forget',
#  'i',
#  'know',
#  'my',
#  'age',
#  'and',
#  'i',
#  'act',
#  'like',
#  'it',
#  'got',
#  'what',
#  'you',
#  'cant',
#  'resist',
#  'im',
#  'a',
#  'perfect',
#  'allamerican',
#  'bitch',
#  'with',
#  'perfect',
#  'allamerican',
#  'lips',
#  'and',
#  'perfect',
#  'allamerican',
#  'hips',
#  'i',
#  'know',
#  'my',
#  'place',
#  'i',
#  'know',
#  'my',
#  'place',
#  'and',
#  'this',
#  'is',
#  'it',
#  'hey',
#  'havent',
#  'heard',
#  'from',
#  'you',
#  'in',
#  'a',
#  'couple',
#  'of',
#  'months',
#  'but',
#  'im',
#  'out',
#  'right',
#  'now',
#  'and',
#  'im',
#  'all',
#  'fucked',
#  'up',
#  'and',
#  'youre',
#  'callin',
#  'my',
#  'phone',
#  'and',
#  'youre',
#  'all',
#  'alone',
#  'and',
#  'im',
#  'sensing',
#  'some',
#  'undertone',
#  'and',
#  'im',
#  'right',
#  'here',
#  'with',
#  'all',
#  'my',
#  'friends',
#  'but',
#  'youre',
#  'sending',
#  'me',
#  'your',
#  'new',
#  'address',
#  'and',
#  'i',
#  'know',
#  'were',
#  'done',
#  'i',
#  'know',
#  'were',
#  'through',
#  'but',
#  'god',
#  'when',
#  'i',
#  'look',
#  'at',
#  'you',
#  'my',
#  'brain',
#  'goes',
#  'ah',
#  'cant',
#  'hear',
#  'my',
#  'thoughts',
#  'i',
#  'can',
#  'not',
#  'hear',
#  'my',
#  'thoughts',
#  'like',
#  'blahblahblah',
#  'blah',
#  'blah',
#  'blah',
#  'blah',
#  'blah',
#  'blah',
#  'should',
#  'probably',
#  'not',
#  'i',
#  'should',
#  'probably',
#  'probably',
#  'not',
#  'i',
#  'should',
#  'probably',
#  'probably',
#  'not',
#  'seeing',
#  'you',
#  'tonight',
#  'its',
#  'a',
#  'bad',
#  'idea',
#  'right',
#  'seeing',
#  'you',
#  'tonight',
#  'its',
#  'a',
#  'bad',
#  'idea',
#  'right',
#  'seeing',
#  'you',
#  'tonight',
#  'its',
#  'a',
#  'bad',
#  'idea',
#  'right',
#  'seeing',
#  'you',
#  'tonight',
#  'fuck',
#  'it',
#  'its',
#  'fine',
#  'yes',
#  'i',
#  'know',
#  'that',
#  'hes',
#  'my',
#  'ex',
#  'but',
#  'cant',
#  'two',
#  'people',
#  'reconnect',
#  'i',
#  'only',
#  'see',
#  'him',
#  'as',
#  'a',
#  'friend',
#  'the',
#  'biggest',
#  'lie',
#  'i',
#  'ever',
#  'said',
#  'oh',
#  'yes',
#  'i',
#  'know',
#  'that',
#  'hes',
#  'my',
#  'ex',
#  'but',
#  'cant',
#  'two',
#  'people',
#  'reconnect',
#  'i',
#  'only',
#  'see',
#  'him',
#  'as',
#  'a',
#  'friend',
#  'i',
#  'just',
#  'tripped',
#  'and',
#  'fell',
#  'into',
#  'his',
#  'bed',
#  'now',
#  'im',
#  'gettin',
#  'in',
#  'the',
#  'car',
#  'wreckin',
#  'all',
#  'my',
#  'plans',
#  'i',
#  'know',
#  'i',
#  'should',
#  'stop',
#  'but',
#  'i',
#  'cant',
#  'and',
#  'i',
#  'told',
#  'my',
#  'friends',
#  'i',
#  'was',
#  'asleep',
#  'but',
#  'i',
#  'never',
#  'said',
#  'where',
#  'or',
#  'in',
#  'whose',
#  'sheets',
#  'and',
#  'i',
#  'pull',
#  'up',
#  'to',
#  'your',
#  'place',
#  'on',
#  'the',
#  'second',
#  'floor',
#  'and',
#  'youre',
#  'standing',
#  'smiling',
#  'at',
#  'the',
#  'door',
#  'and',
#  'im',
#  'sure',
#  'ive',
#  'seen',
#  'much',
#  'hotter',
#  'men',
#  'but',
#  'i',
#  'really',
#  'cant',
#  'remember',
#  'when',
#  'my',
#  'brain',
#  'goes',
#  'ah',
#  'cant',
#  'hear',
#  'my',
#  'thoughts',
#  'i',
#  'can',
#  'not',
#  'hear',
#  'my',
#  'thoughts',
#  'like',
#  'blahblahblah',
#  'blah',
#  'blah',
#  'blah',
#  'blah',
#  'blah',
#  'blah',
#  'should',
#  'probably',
#  'not',
#  'i',
#  'should',
#  'probably',
#  'probably',
#  'not',
#  'i',
#  'should',
#  'probably',
#  'probably',
#  'not',
#  'seeing',
#  'you',
#  'tonight',
#  'its',
#  'a',
#  'bad',
#  'idea',
#  'right',
#  'seeing',
#  'you',
#  'tonight',
#  'its',
#  'a',
#  'bad',
#  'idea',
#  'right',
#  'seeing',
#  'you',
#  'tonight',
#  'its',
#  'a',
#  'bad',
#  'idea',
#  'right',
#  'seeing',
#  'you',
#  'tonight',
#  'fuck',
#  'it',
#  'its',
#  'fine',
#  'yes',
#  'i',
#  'know',
#  'that',
#  'hes',
#  'my',
#  'ex',
#  'but',
#  'cant',
#  'two',
#  'people',
#  'reconnect',
#  'i',
#  'only',
#  'see',
#  'him',
#  'as',
#  'a',
#  'friend',
#  'the',
#  'biggest',
#  'lie',
#  'i',
#  'ever',
#  'said',
#  'oh',
#  'yes',
#  'i',
#  'know',
#  'that',
#  'hes',
#  'my',
#  'ex',
#  'but',
#  'cant',
#  'two',
#  'people',
#  'reconnect',
#  'i',
#  'only',
#  'see',
#  'him',
#  'as',
#  'a',
#  'friend',
#  'i',
#  'just',
#  'tripped',
#  'and',
#  'fell',
#  'into',
#  'his',
#  'bed',
#  'oh',
#  'yes',
#  'i',
#  'know',
#  'that',
#  'hes',
#  'my',
#  'ex',
#  'cant',
#  'two',
#  'people',
#  'reconnect',
#  'the',
#  'biggest',
#  'lie',
#  'i',
#  'ever',
#  'said',
#  'i',
#  'just',
#  'tripped',
#  'and',
#  'fell',
#  'into',
#  'his',
#  'bed',
#  'my',
#  'brain',
#  'goes',
#  'ah',
#  'cant',
#  'hear',
#  'my',
#  'thoughts',
#  'the',
#  'biggest',
#  'lie',
#  'i',
#  'ever',
#  'said',
#  'my',
#  'brain',
#  'goes',
#  'ah',
#  'cant',
#  'hear',
#  'my',
#  'thoughts',
#  'i',
#  'just',
#  'tripped',
#  'and',
#  'fell',
#  'into',
#  'his',
#  'bed',
#  'thoughts',
#  'blah',
#  'thoughts',
#  'blah',
#  'hate',
#  'to',
#  'give',
#  'the',
#  'satisfaction',
#  'asking',
#  'how',
#  'youre',
#  'doing',
#  'now',
#  'hows',
#  'the',
#  'castle',
#  'built',
#  'off',
#  'people',
#  'you',
#  'pretend',
#  'to',
#  'care',
#  'about',
#  'just',
#  'what',
#  'you',
#  'wanted',
#  'look',
#  'at',
#  'you',
#  'cool',
#  'guy',
#  'you',
#  'got',
#  'it',
#  'i',
#  'see',
#  'the',
#  'parties',
#  'and',
#  'the',
#  'diamonds',
#  'sometimes',
#  'when',
#  'i',
#  'close',
#  'my',
#  'eyes',
#  'six',
#  'months',
#  'of',
#  'torture',
#  'you',
#  'sold',
#  'as',
#  'some',
#  'forbidden',
#  'paradise',
#  'i',
#  'loved',
#  'you',
#  'truly',
#  'you',
#  'got',
#  'ta',
#  'laugh',
#  'at',
#  'the',
#  'stupidity',
#  'cause',
#  'ive',
#  'made',
#  'some',
#  'real',
#  'big',
#  'mistakes',
#  'but',
#  'you',
#  'make',
#  'the',
#  'worst',
#  'one',
#  'look',
#  'fine',
#  'i',
#  'shouldve',
#  'known',
#  'it',
#  'was',
#  'strange',
#  'you',
#  'only',
#  'come',
#  'out',
#  'at',
#  'night',
#  'i',
#  'used',
#  'to',
#  'think',
#  'i',
#  'was',
#  'smart',
#  'but',
#  'you',
#  'made',
#  'me',
#  'look',
#  'so',
#  'naive',
#  'the',
#  'way',
#  'you',
#  'sold',
#  'me',
#  'for',
#  'parts',
#  'as',
#  'you',
#  'sunk',
#  'your',
#  'teeth',
#  'into',
#  'me',
#  'oh',
#  'bloodsucker',
#  'fame',
#  'fucker',
#  'bleedin',
#  'me',
#  'dry',
#  'like',
#  'a',
#  'goddamn',
#  'vampire',
#  'and',
#  'every',
#  'girl',
#  'i',
#  'ever',
#  'talked',
#  'to',
#  'told',
#  'me',
#  'you',
#  'were',
#  'bad',
#  'bad',
#  'news',
#  'you',
#  'called',
#  'them',
#  'crazy',
#  'god',
#  'i',
#  'hate',
#  'the',
#  'way',
#  'i',
#  'called',
#  'em',
#  'crazy',
#  'too',
#  'youre',
#  'so',
#  'convincing',
#  'how',
#  'do',
#  'you',
#  'lie',
#  'without',
#  'flinching',
#  'how',
#  'do',
#  'you',
#  'lie',
#  'how',
#  'do',
#  'you',
#  'lie',
#  'how',
#  'do',
#  'you',
#  'lie',
#  'oh',
#  'what',
#  'a',
#  'mesmerizing',
#  'paralyzing',
#  'fucked',
#  'up',
#  'little',
#  'thrill',
#  'cant',
#  'figure',
#  'out',
#  'just',
#  'how',
#  'you',
#  'do',
#  'it',
#  'and',
#  'god',
#  'knows',
#  'i',
#  'never',
#  'will',
#  'went',
#  'for',
#  'me',
#  'and',
#  'not',
#  'her',
#  'cause',
#  'girls',
#  'your',
#  'age',
#  'know',
#  'better',
#  'ive',
#  'made',
#  'some',
#  'real',
#  'big',
#  'mistakes',
#  'but',
#  'you',
#  'make',
#  'the',
#  'worst',
#  'one',
#  'look',
#  'fine',
#  'i',
#  'shouldve',
#  'known',
#  'it',
#  'was',
#  'strange',
#  'you',
#  'only',
#  'come',
#  'out',
#  'at',
#  'night',
#  'i',
#  'used',
#  'to',
#  'think',
#  'i',
#  'was',
#  'smart',
#  'but',
#  'you',
#  'made',
#  'me',
#  'look',
#  'so',
#  'naive',
#  'the',
#  'way',
#  'you',
#  'sold',
#  'me',
#  'for',
#  'parts',
#  'as',
#  'you',
#  'sunk',
#  'your',
#  'teeth',
#  'into',
#  'me',
#  'oh',
#  'bloodsucker',
#  'fame',
#  'fucker',
#  'bleedin',
#  'me',
#  'dry',
#  'like',
#  'a',
#  'goddamn',
#  'vampire',
#  'ah',
#  'you',
#  'said',
#  'it',
#  'was',
#  'true',
#  'love',
#  'but',
#  'wouldnt',
#  'that',
#  'be',
#  'hard',
#  'you',
#  'cant',
#  'love',
#  'anyone',
#  'cause',
#  'that',
#  'would',
#  'mean',
#  'you',
#  'had',
#  'a',
#  'heart',
#  'i',
#  'tried',
#  'to',
#  'help',
#  'you',
#  'out',
#  'now',
#  'i',
#  'know',
#  'that',
#  'i',
#  'cant',
#  'cause',
#  'how',
#  'you',
#  'thinks',
#  'the',
#  'kind',
#  'of',
#  'thing',
#  'ill',
#  'never',
#  'understand',
#  'ive',
#  'made',
#  'some',
#  'real',
#  'big',
#  'mistakes',
#  'but',
#  'you',
#  'make',
#  'the',
#  'worst',
#  'one',
#  'look',
#  'fine',
#  'i',
#  'shouldve',
#  'known',
#  'it',
#  'was',
#  'strange',
#  'you',
#  'only',
#  'come',
#  'out',
#  'at',
#  'night',
#  'i',
#  'used',
#  'to',
#  'think',
#  'i',
#  'was',
#  'smart',
#  'but',
#  'you',
#  'made',
#  'me',
#  'look',
#  'so',
#  'naive',
#  'the',
#  'way',
#  'you',
#  'sold',
#  'me',
#  'for',
#  'parts',
#  'as',
#  'you',
#  'sunk',
#  'your',
#  'teeth',
#  'into',
#  'me',
#  'oh',
#  'bloodsucker',
#  ...]

# %%
word_frequency = collections.Counter(word_list)
word_frequency = sorted(word_frequency.items(), key=lambda x: x[1], reverse=True)

word_frequency
# Out:
# [('i', 331),
#  ('and', 127),
#  ('you', 125),
#  ('the', 118),
#  ('my', 79),
#  ('it', 78),
#  ('to', 70),
#  ('but', 66),
#  ('him', 61),
#  ('me', 59),
#  ('a', 54),
#  ('im', 50),
#  ('that', 50),
#  ('oh', 48),
#  ('all', 46),
#  ('its', 43),
#  ('back', 39),
#  ('get', 37),
#  ('na', 37),
#  ('know', 34),
#  ('so', 33),
#  ('like', 31),
#  ('up', 30),
#  ('wan', 30),
#  ('of', 29),
#  ('in', 28),
#  ('want', 28),
#  ('dont', 26),
#  ('then', 25),
#  ('cant', 24),
#  ('as', 23),
#  ('your', 23),
#  ('just', 22),
#  ('do', 22),
#  ('for', 21),
#  ('got', 20),
#  ('is', 20),
#  ('was', 20),
#  ('feel', 19),
#  ('not', 19),
#  ('love', 18),
#  ('out', 18),
#  ('when', 18),
#  ('bed', 18),
#  ('cause', 18),
#  ('better', 18),
#  ('try', 18),
#  ('with', 17),
#  ('what', 17),
#  ('be', 17),
#  ('every', 16),
#  ('gets', 16),
#  ('yeah', 15),
#  ('at', 15),
#  ('never', 15),
#  ('how', 15),
#  ('made', 15),
#  ('say', 15),
#  ('logical', 15),
#  ('make', 14),
#  ('ive', 14),
#  ('god', 14),
#  ('blah', 14),
#  ('on', 14),
#  ('they', 14),
#  ('pretty', 14),
#  ('am', 13),
#  ('people', 13),
#  ('youre', 13),
#  ('some', 13),
#  ('said', 13),
#  ('his', 13),
#  ('thing', 13),
#  ('social', 13),
#  ('suicide', 13),
#  ('he', 13),
#  ('two', 12),
#  ('over', 12),
#  ('could', 12),
#  ('ahah', 12),
#  ('makin', 12),
#  ('only', 11),
#  ('right', 11),
#  ('now', 11),
#  ('ah', 11),
#  ('bad', 11),
#  ('think', 11),
#  ('tried', 11),
#  ('whos', 11),
#  ('probably', 10),
#  ('care', 10),
#  ('one', 10),
#  ('another', 10),
#  ('this', 9),
#  ('look', 9),
#  ('fine', 9),
#  ('fell', 9),
#  ('into', 9),
#  ('really', 9),
#  ('give', 9),
#  ('tell', 9),
#  ('time', 9),
#  ('life', 9),
#  ('good', 9),
#  ('if', 9),
#  ('hear', 8),
#  ('thoughts', 8),
#  ('should', 8),
#  ('seeing', 8),
#  ('tonight', 8),
#  ('hes', 8),
#  ('see', 8),
#  ('lie', 8),
#  ('ever', 8),
#  ('stop', 8),
#  ('told', 8),
#  ('night', 8),
#  ('lacy', 8),
#  ('been', 8),
#  ('head', 8),
#  ('enough', 8),
#  ('things', 7),
#  ('mean', 7),
#  ('friends', 7),
#  ('tripped', 7),
#  ('guy', 7),
#  ('way', 7),
#  ('girl', 7),
#  ('ill', 7),
#  ('did', 7),
#  ('weird', 7),
#  ('always', 7),
#  ('everything', 7),
#  ('again', 7),
#  ('gon', 7),
#  ('more', 7),
#  ('isnt', 7),
#  ('forgive', 6),
#  ('idea', 6),
#  ('friend', 6),
#  ('real', 6),
#  ('come', 6),
#  ('well', 6),
#  ('ooh', 6),
#  ('go', 6),
#  ('let', 6),
#  ('loves', 6),
#  ('embarrassing', 6),
#  ('being', 6),
#  ('little', 5),
#  ('best', 5),
#  ('perfect', 5),
#  ('goddamn', 5),
#  ('from', 5),
#  ('were', 5),
#  ('yes', 5),
#  ('ex', 5),
#  ('reconnect', 5),
#  ('where', 5),
#  ('hate', 5),
#  ('about', 5),
#  ('parts', 5),
#  ('her', 5),
#  ('would', 5),
#  ('heart', 5),
#  ('hell', 5),
#  ('takes', 5),
#  ('guess', 5),
#  ('wrong', 5),
#  ('start', 5),
#  ('still', 5),
#  ('have', 5),
#  ('why', 5),
#  ('makes', 5),
#  ('miss', 5),
#  ('face', 5),
#  ('fucking', 5),
#  ('change', 5),
#  ('light', 4),
#  ('sure', 4),
#  ('built', 4),
#  ('sun', 4),
#  ('age', 4),
#  ('allamerican', 4),
#  ('curl', 4),
#  ('phone', 4),
#  ('new', 4),
#  ('brain', 4),
#  ('goes', 4),
#  ('can', 4),
#  ('biggest', 4),
#  ('car', 4),
#  ('sheets', 4),
#  ('pull', 4),
#  ('second', 4),
#  ('sometimes', 4),
#  ('sold', 4),
#  ('known', 4),
#  ('used', 4),
#  ('smart', 4),
#  ('will', 4),
#  ('had', 4),
#  ('jealous', 4),
#  ('no', 4),
#  ('words', 4),
#  ('each', 4),
#  ('ahahahahahah', 4),
#  ('whole', 4),
#  ('lalalalalala', 4),
#  ('changin', 4),
#  ('id', 4),
#  ('myself', 4),
#  ('couldnt', 4),
#  ('pour', 4),
#  ('sad', 4),
#  ('even', 4),
#  ('watch', 4),
#  ('worth', 4),
#  ('tough', 4),
#  ('strength', 4),
#  ('grow', 4),
#  ('place', 3),
#  ('alone', 3),
#  ('done', 3),
#  ('through', 3),
#  ('gettin', 3),
#  ('much', 3),
#  ('off', 3),
#  ('eyes', 3),
#  ('big', 3),
#  ('mistakes', 3),
#  ('worst', 3),
#  ('shouldve', 3),
#  ('strange', 3),
#  ('naive', 3),
#  ('sunk', 3),
#  ('teeth', 3),
#  ('bloodsucker', 3),
#  ('fame', 3),
#  ('fucker', 3),
#  ('bleedin', 3),
#  ('dry', 3),
#  ('vampire', 3),
#  ('called', 3),
#  ('them', 3),
#  ('too', 3),
#  ('skin', 3),
#  ('lately', 3),
#  ('are', 3),
#  ('outside', 3),
#  ('fun', 3),
#  ('broke', 3),
#  ('glass', 3),
#  ('secrets', 3),
#  ('shouldnt', 3),
#  ('stumbled', 3),
#  ('worse', 3),
#  ('die', 3),
#  ('after', 3),
#  ('mom', 3),
#  ('away', 3),
#  ('club', 3),
#  ('dream', 3),
#  ('plus', 3),
#  ('equals', 3),
#  ('five', 3),
#  ('rain', 3),
#  ('shine', 3),
#  ('possible', 3),
#  ('lied', 3),
#  ('stopped', 3),
#  ('an', 3),
#  ('something', 3),
#  ('hed', 3),
#  ('sweet', 3),
#  ('revenge', 3),
#  ('hurt', 3),
#  ('lunch', 3),
#  ('same', 3),
#  ('crucify', 3),
#  ('string', 3),
#  ('loser', 3),
#  ('mentionin', 3),
#  ('long', 3),
#  ('sorry', 3),
#  ('bought', 3),
#  ('everybodys', 3),
#  ('keepin', 3),
#  ('feather', 2),
#  ('ignore', 2),
#  ('thats', 2),
#  ('forget', 2),
#  ('act', 2),
#  ('resist', 2),
#  ('hair', 2),
#  ('months', 2),
#  ('fucked', 2),
#  ('blahblahblah', 2),
#  ('fuck', 2),
#  ('remember', 2),
#  ('doing', 2),
#  ('castle', 2),
#  ('wanted', 2),
#  ('cool', 2),
#  ('parties', 2),
#  ('torture', 2),
#  ('loved', 2),
#  ('laugh', 2),
#  ('talked', 2),
#  ('crazy', 2),
#  ('girls', 2),
#  ('hard', 2),
#  ('anyone', 2),
#  ('understand', 2),
#  ('arent', 2),
#  ('sweetest', 2),
#  ('angel', 2),
#  ('greatest', 2),
#  ('despise', 2),
#  ('mind', 2),
#  ('blood', 2),
#  ('joke', 2),
#  ('clothes', 2),
#  ('feels', 2),
#  ('doesnt', 2),
#  ('step', 2),
#  ('conversation', 2),
#  ('boys', 2),
#  ('day', 2),
#  ('alive', 2),
#  ('thought', 2),
#  ('throw', 2),
#  ('took', 2),
#  ('drunk', 2),
#  ('fairweather', 2),
#  ('push', 2),
#  ('who', 2),
#  ('tired', 2),
#  ('bein', 2),
#  ('has', 2),
#  ('turned', 2),
#  ('somethin', 2),
#  ('dread', 2),
#  ('playin', 2),
#  ('victim', 2),
#  ('red', 2),
#  ('sky', 2),
#  ('high', 2),
#  ('thinkin', 2),
#  ('those', 2),
#  ('lovin', 2),
#  ('young', 2),
#  ('take', 2),
#  ('stupid', 2),
#  ('half', 2),
#  ('responsible', 2),
#  ('horrible', 2),
#  ('couldve', 2),
#  ('didnt', 2),
#  ('song', 2),
#  ('everyone', 2),
#  ('shit', 2),
#  ('fix', 2),
#  ('key', 2),
#  ('break', 2),
#  ('stitch', 2),
#  ('kiss', 2),
#  ('uppercut', 2),
#  ('meet', 2),
#  ('son', 2),
#  ('sucks', 2),
#  ('week', 2),
#  ('started', 2),
#  ('world', 2),
#  ('war', 2),
#  ('keep', 2),
#  ('comin', 2),
#  ('givin', 2),
#  ('call', 2),
#  ('hold', 2),
#  ('scream', 2),
#  ('anybody', 2),
#  ('easily', 2),
#  ('strong', 2),
#  ('mirror', 2),
#  ('must', 2),
#  ('insecure', 2),
#  ('theres', 2),
#  ('body', 2),
#  ('lipstick', 2),
#  ('shade', 2),
#  ('win', 2),
#  ('none', 2),
#  ('wise', 2),
#  ('years', 2),
#  ('blow', 2),
#  ('candles', 2),
#  ('happy', 2),
#  ('birthday', 2),
#  ('ahead', 2),
#  ('nineteen', 2),
#  ('fear', 2),
#  ('already', 2),
#  ('teenage', 2),
#  ('stiff', 1),
#  ('board', 1),
#  ('pay', 1),
#  ('attention', 1),
#  ('most', 1),
#  ('alright', 1),
#  ('movies', 1),
#  ('jokes', 1),
#  ('bout', 1),
#  ('senseless', 1),
#  ('cruelty', 1),
#  ('mother', 1),
#  ('total', 1),
#  ('machine', 1),
#  ('issue', 1),
#  ('darkness', 1),
#  ('motherfuckin', 1),
#  ('pocket', 1),
#  ('believe', 1),
#  ('fresh', 1),
#  ('air', 1),
#  ('cocacola', 1),
#  ('bottles', 1),
#  ('use', 1),
#  ('class', 1),
#  ('integrity', 1),
#  ('kennedy', 1),
#  ('swear', 1),
#  ('spare', 1),
#  ('bitch', 1),
#  ('lips', 1),
#  ('hips', 1),
#  ('hey', 1),
#  ('havent', 1),
#  ('heard', 1),
#  ('couple', 1),
#  ('callin', 1),
#  ('sensing', 1),
#  ('undertone', 1),
#  ('here', 1),
#  ('sending', 1),
#  ('address', 1),
#  ('wreckin', 1),
#  ('plans', 1),
#  ('asleep', 1),
#  ('or', 1),
#  ('whose', 1),
#  ('floor', 1),
#  ('standing', 1),
#  ('smiling', 1),
#  ('door', 1),
#  ('seen', 1),
#  ('hotter', 1),
#  ('men', 1),
#  ('satisfaction', 1),
#  ('asking', 1),
#  ('hows', 1),
#  ('pretend', 1),
#  ('diamonds', 1),
#  ('close', 1),
#  ('six', 1),
#  ('forbidden', 1),
#  ('paradise', 1),
#  ('truly', 1),
#  ('ta', 1),
#  ('stupidity', 1),
#  ('news', 1),
#  ('em', 1),
#  ('convincing', 1),
#  ('without', 1),
#  ('flinching', 1),
#  ('mesmerizing', 1),
#  ('paralyzing', 1),
#  ('thrill', 1),
#  ('figure', 1),
#  ('knows', 1),
#  ('went', 1),
#  ('true', 1),
#  ('wouldnt', 1),
#  ('help', 1),
#  ('thinks', 1),
#  ('kind', 1),
#  ('puff', 1),
#  ('pastry', 1),
#  ('side', 1),
#  ('dear', 1),
#  ('white', 1),
#  ('daisies', 1),
#  ('doin', 1),
#  ('perfume', 1),
#  ('wear', 1),
#  ('linger', 1),
#  ('watching', 1),
#  ('hidden', 1),
#  ('plain', 1),
#  ('sight', 1),
#  ('everywhere', 1),
#  ('bear', 1),
#  ('sexy', 1),
#  ('losin', 1),
#  ('compliments', 1),
#  ('likе', 1),
#  ('bullets', 1),
#  ('dazzling', 1),
#  ('starlet', 1),
#  ('bardot', 1),
#  ('reincarnatе', 1),
#  ('exist', 1),
#  ('ribbons', 1),
#  ('stomachs', 1),
#  ('knots', 1),
#  ('rationalize', 1),
#  ('dust', 1),
#  ('poison', 1),
#  ('loathe', 1),
#  ('rotten', 1),
#  ('worships', 1),
#  ('cat', 1),
#  ('tongue', 1),
#  ('along', 1),
#  ('running', 1),
#  ('cold', 1),
#  ('inside', 1),
#  ('fit', 1),
#  ('bones', 1),
#  ('partys', 1),
#  ('laughed', 1),
#  ('sat', 1),
#  ('uhhuh', 1),
#  ('searchin', 1),
#  ('website', 1),
#  ('flirt', 1),
#  ('hot', 1),
#  ('swore', 1),
#  ('type', 1),
#  ('everythin', 1),
#  ('tragic', 1),
#  ('gay', 1),
#  ('morning', 1),
#  ('panic', 1),
#  ('shocked', 1),
#  ('wife', 1),
#  ('name', 1),
#  ('twice', 1),
#  ('third', 1),
#  ('line', 1),
#  ('ugh', 1),
#  ('ruined', 1),
#  ('piece', 1),
#  ('plastic', 1),
#  ('nothing', 1),
#  ('pretendin', 1),
#  ('older', 1),
#  ('than', 1),
#  ('moment', 1),
#  ('mine', 1),
#  ('forced', 1),
#  ('sign', 1),
#  ('wake', 1),
#  ('recurrin', 1),
#  ('drivin', 1),
#  ('city', 1),
#  ('brakes', 1),
#  ('swerve', 1),
#  ('road', 1),
#  ('read', 1),
#  ('somewhere', 1),
#  ('control', 1),
#  ('someone', 1),
#  ('distraction', 1),
#  ('tourist', 1),
#  ('attraction', 1),
#  ('theyre', 1),
#  ('machinery', 1),
#  ('happen', 1),
#  ('imagined', 1),
#  ('countin', 1),
#  ('beautiful', 1),
#  ('regret', 1),
#  ('ohoh', 1),
#  ('master', 1),
#  ('manipulator', 1),
#  ('savior', 1),
#  ('put', 1),
#  ('rumors', 1),
#  ('denied', 1),
#  ('water', 1),
#  ('falls', 1),
#  ('february', 1),
#  ('currents', 1),
#  ('stronger', 1),
#  ('convinced', 1),
#  ('baby', 1),
#  ('thinking', 1),
#  ('giant', 1),
#  ('walls', 1),
#  ('unraveled', 1),
#  ('green', 1),
#  ('grass', 1),
#  ('our', 1),
#  ('problems', 1),
#  ('solvable', 1),
#  ('argument', 1),
#  ('held', 1),
#  ('brought', 1),
#  ('instead', 1),
#  ('soft', 1),
#  ('three', 1),
#  ('wait', 1),
#  ('drums', 1),
#  ('met', 1),
#  ('summer', 1),
#  ('left', 1),
#  ('spring', 1),
#  ('argued', 1),
#  ('ego', 1),
#  ('temper', 1),
#  ('wandering', 1),
#  ('eye', 1),
#  ('sixfoottwo', 1),
#  ('dude', 1),
#  ('nice', 1),
#  ('such', 1),
#  ('us', 1),
#  ('end', 1),
#  ('bar', 1),
#  ('dance', 1),
#  ('fly', 1),
#  ('france', 1),
#  ('nights', 1),
#  ('feeling', 1),
#  ('depressed', 1),
#  ('til', 1),
#  ('pass', 1),
#  ('down', 1),
#  ('choose', 1),
#  ('write', 1),
#  ('these', 1),
#  ('letters', 1),
#  ('trash', 1),
#  ('kisses', 1),
#  ('hitting', 1),
#  ('send', 1),
#  ('picture', 1),
#  ('faces', 1),
#  ('disappointed', 1),
#  ('because', 1),
#  ('knew', 1),
#  ('wasnt', 1),
#  ('truth', 1),
#  ('trippin', 1),
#  ('fathers', 1),
#  ('daughter', 1),
#  ('maybe', 1),
#  ('woohoo', 1),
#  ('woo', 1),
#  ('hit', 1),
#  ('month', 1),
#  ('kissed', 1),
#  ('school', 1),
#  ('stayed', 1),
#  ('space', 1),
#  ('need', 1),
#  ('waited', 1),
#  ('by', 1),
#  ('fool', 1),
#  ('consoled', 1),
#  ('while', 1),
#  ('cried', 1),
#  ('exgirlfriends', 1),
#  ('found', 1),
#  ('version', 1),
#  ('damn', 1),
#  ('near', 1),
#  ('iii', 1),
#  ('jesus', 1),
#  ('placed', 1),
#  ('bets', 1),
#  ('anything', 1),
#  ('plannin', 1),
#  ('wedding', 1),
#  ('marryin', 1),
#  ('nightmares', 1),
#  ('friday', 1),
#  ('may', 1),
#  ('entire', 1),
#  ('changed', 1),
#  ('trust', 1),
#  ('betrayed', 1),
#  ('confusion', 1),
#  ('lingers', 1),
#  ('crushed', 1),
#  ('between', 1),
#  ('fingers', 1),
#  ('doubt', 1),
#  ('damage', 1),
#  ('detail', 1),
#  ('depends', 1),
#  ('undying', 1),
#  ('grudge', 1),
#  ('voice', 1),
#  ('arguments', 1),
#  ('won', 1),
#  ('against', 1),
#  ('shower', 1),
#  ('before', 1),
#  ('guilty', 1),
#  ('fantasize', 1),
#  ('unhappy', 1),
#  ('we', 1),
#  ('both', 1),
#  ('drew', 1),
#  ('man', 1),
#  ('cuts', 1),
#  ('equal', 1),
#  ('deserved', 1),
#  ('flowers', 1),
#  ('filled', 1),
#  ('vitriol', 1),
#  ('fall', 1),
#  ('quite', 1),
#  ('there', 1),
#  ('yet', 1),
#  ('bunch', 1),
#  ('makeup', 1),
#  ('tryna', 1),
#  ('cover', 1),
#  ('skip', 1),
#  ('eatin', 1),
#  ('cake', 1),
#  ('birthdays', 1),
#  ('prescription', 1),
#  ('stay', 1),
#  ('calm', 1),
#  ('missin', 1),
#  ('looks', 1),
#  ('anyways', 1),
#  ('battle', 1),
#  ('youll', 1),
#  ('hated', 1),
#  ('youd', 1),
#  ('posters', 1),
#  ('wall', 1),
#  ('shitty', 1),
#  ('magazines', 1),
#  ('bring', 1),
#  ('around', 1),
#  ('buy', 1),
#  ('chased', 1),
#  ('dumb', 1),
#  ('ideal', 1),
#  ('matters', 1),
#  ('ends', 1),
#  ('itll', 1),
#  ('beyond', 1),
#  ('guys', 1),
#  ('great', 1),
#  ('quietly', 1),
#  ('misunderstood', 1),
#  ('does', 1),
#  ('wideeyed', 1),
#  ('affection', 1),
#  ('intentions', 1),
#  ('reason', 1),
#  ('bluffs', 1),
#  ('excuses', 1),
#  ('learning', 1),
#  ('lessons', 1),
#  ('spend', 1),
#  ('rest', 1),
#  ('wishing', 1),
#  ('recording', 1),
#  ('course', 1)]

# %%
#run this cell to see how the sentiment analyzer works
sia = SentimentIntensityAnalyzer()
sia.polarity_scores("I love BTS!")
# Out:
# {'neg': 0.0, 'neu': 0.182, 'pos': 0.818, 'compound': 0.6696}

# %%
lyrics['polarity'] = lyrics['clean_lyrics'].apply(lambda x: sia.polarity_scores(x))

# %%
lyrics[['neg', 'neu', 'pos', 'compound']] = lyrics['polarity'].apply(pd.Series)
lyrics.drop('polarity', axis=1)
# Out:
#                             title  \
# 0              all-american bitch
# 1                 bad idea right?
# 2                         vampire
# 3                            lacy
# 4   ballad of a homeschooled girl
# 5                  making the bed
# 6                         logical
# 7                    get him back
# 8             love is embarassing
# 9                      the grudge
# 10            pretty isn’t pretty
# 11                  teenage dream
#
#                                                lyrics  \
# 0   I am light as a feather, I'm as stiff as a boa...
# 1   Hey\nHaven't heard from you in a couple of mon...
# 2   Hate to give the satisfaction asking how you'r...
# 3   Lacy, oh Lacy, skin like puff pastry\nAren't y...
# 4   Cat got my tongue\nAnd I don't think I get alo...
# 5   Want it, so I got it, did it, so it's done\nAn...
# 6   Master manipulator\nGod, you're so good at wha...
# 7   One, two, three\nWait, is this the song with t...
# 8   I told my friends you were the one\nAfter I'd ...
# 9   I have nightmares each week about that Friday ...
# 10  Bought a bunch of makeup\nTryna' cover up my f...
# 11  When am I gonna stop being wise beyond my year...
#
#                                          clean_lyrics  \
# 0   i am light as a feather im as stiff as a board...
# 1   hey\nhavent heard from you in a couple of mont...
# 2   hate to give the satisfaction asking how youre...
# 3   lacy oh lacy skin like puff pastry\narent you ...
# 4   cat got my tongue\nand i dont think i get alon...
# 5   want it so i got it did it so its done\nanothe...
# 6   master manipulator\ngod youre so good at what ...
# 7   one two three\nwait is this the song with the ...
# 8   i told my friends you were the one\nafter id k...
# 9   i have nightmares each week about that friday ...
# 10  bought a bunch of makeup\ntryna cover up my fa...
# 11  when am i gonna stop being wise beyond my year...
#
#                                            lyrics_tok    neg    neu    pos  \
# 0   [i, am, light, as, a, feather, im, as, stiff, ...  0.170  0.650  0.180
# 1   [hey, havent, heard, from, you, in, a, couple,...  0.151  0.715  0.134
# 2   [hate, to, give, the, satisfaction, asking, ho...  0.220  0.600  0.179
# 3   [lacy, oh, lacy, skin, like, puff, pastry, are...  0.158  0.639  0.203
# 4   [cat, got, my, tongue, and, i, dont, think, i,...  0.285  0.654  0.061
# 5   [want, it, so, i, got, it, did, it, so, its, d...  0.134  0.727  0.140
# 6   [master, manipulator, god, youre, so, good, at...  0.112  0.675  0.214
# 7   [one, two, three, wait, is, this, the, song, w...  0.156  0.665  0.178
# 8   [i, told, my, friends, you, were, the, one, af...  0.244  0.625  0.131
# 9   [i, have, nightmares, each, week, about, that,...  0.169  0.681  0.150
# 10  [bought, a, bunch, of, makeup, tryna, cover, u...  0.112  0.670  0.218
# 11  [when, am, i, gon, na, stop, being, wise, beyo...  0.071  0.634  0.295
#
#     compound
# 0     0.2569
# 1    -0.2617
# 2    -0.9833
# 3     0.8257
# 4    -0.9984
# 5     0.6841
# 6     0.9945
# 7    -0.0465
# 8    -0.9689
# 9    -0.6454
# 10    0.9909
# 11    0.9984

# %%
#calculate overall sentiment for pos, neg, sentiment
pos = sum(lyrics['pos'])
neg = sum(lyrics['neg'])
compound = sum(lyrics['compound'])

#print the overall sentiments
print("positive: ", pos)
print("negative: ", neg)
print("compound: ", compound)
# Out:
# positive:  2.0829999999999997
# negative:  1.982
# compound:  0.8463000000000002

# %%
lyrics
# Out:
#                             title  \
# 0              all-american bitch
# 1                 bad idea right?
# 2                         vampire
# 3                            lacy
# 4   ballad of a homeschooled girl
# 5                  making the bed
# 6                         logical
# 7                    get him back
# 8             love is embarassing
# 9                      the grudge
# 10            pretty isn’t pretty
# 11                  teenage dream
#
#                                                lyrics  \
# 0   I am light as a feather, I'm as stiff as a boa...
# 1   Hey\nHaven't heard from you in a couple of mon...
# 2   Hate to give the satisfaction asking how you'r...
# 3   Lacy, oh Lacy, skin like puff pastry\nAren't y...
# 4   Cat got my tongue\nAnd I don't think I get alo...
# 5   Want it, so I got it, did it, so it's done\nAn...
# 6   Master manipulator\nGod, you're so good at wha...
# 7   One, two, three\nWait, is this the song with t...
# 8   I told my friends you were the one\nAfter I'd ...
# 9   I have nightmares each week about that Friday ...
# 10  Bought a bunch of makeup\nTryna' cover up my f...
# 11  When am I gonna stop being wise beyond my year...
#
#                                          clean_lyrics  \
# 0   i am light as a feather im as stiff as a board...
# 1   hey\nhavent heard from you in a couple of mont...
# 2   hate to give the satisfaction asking how youre...
# 3   lacy oh lacy skin like puff pastry\narent you ...
# 4   cat got my tongue\nand i dont think i get alon...
# 5   want it so i got it did it so its done\nanothe...
# 6   master manipulator\ngod youre so good at what ...
# 7   one two three\nwait is this the song with the ...
# 8   i told my friends you were the one\nafter id k...
# 9   i have nightmares each week about that friday ...
# 10  bought a bunch of makeup\ntryna cover up my fa...
# 11  when am i gonna stop being wise beyond my year...
#
#                                            lyrics_tok  \
# 0   [i, am, light, as, a, feather, im, as, stiff, ...
# 1   [hey, havent, heard, from, you, in, a, couple,...
# 2   [hate, to, give, the, satisfaction, asking, ho...
# 3   [lacy, oh, lacy, skin, like, puff, pastry, are...
# 4   [cat, got, my, tongue, and, i, dont, think, i,...
# 5   [want, it, so, i, got, it, did, it, so, its, d...
# 6   [master, manipulator, god, youre, so, good, at...
# 7   [one, two, three, wait, is, this, the, song, w...
# 8   [i, told, my, friends, you, were, the, one, af...
# 9   [i, have, nightmares, each, week, about, that,...
# 10  [bought, a, bunch, of, makeup, tryna, cover, u...
# 11  [when, am, i, gon, na, stop, being, wise, beyo...
#
#                                              polarity    neg    neu    pos  \
# 0   {'neg': 0.17, 'neu': 0.65, 'pos': 0.18, 'compo...  0.170  0.650  0.180
# 1   {'neg': 0.151, 'neu': 0.715, 'pos': 0.134, 'co...  0.151  0.715  0.134
# 2   {'neg': 0.22, 'neu': 0.6, 'pos': 0.179, 'compo...  0.220  0.600  0.179
# 3   {'neg': 0.158, 'neu': 0.639, 'pos': 0.203, 'co...  0.158  0.639  0.203
# 4   {'neg': 0.285, 'neu': 0.654, 'pos': 0.061, 'co...  0.285  0.654  0.061
# 5   {'neg': 0.134, 'neu': 0.727, 'pos': 0.14, 'com...  0.134  0.727  0.140
# 6   {'neg': 0.112, 'neu': 0.675, 'pos': 0.214, 'co...  0.112  0.675  0.214
# 7   {'neg': 0.156, 'neu': 0.665, 'pos': 0.178, 'co...  0.156  0.665  0.178
# 8   {'neg': 0.244, 'neu': 0.625, 'pos': 0.131, 'co...  0.244  0.625  0.131
# 9   {'neg': 0.169, 'neu': 0.681, 'pos': 0.15, 'com...  0.169  0.681  0.150
# 10  {'neg': 0.112, 'neu': 0.67, 'pos': 0.218, 'com...  0.112  0.670  0.218
# 11  {'neg': 0.071, 'neu': 0.634, 'pos': 0.295, 'co...  0.071  0.634  0.295
#
#     compound
# 0     0.2569
# 1    -0.2617
# 2    -0.9833
# 3     0.8257
# 4    -0.9984
# 5     0.6841
# 6     0.9945
# 7    -0.0465
# 8    -0.9689
# 9    -0.6454
# 10    0.9909
# 11    0.9984

# %%
lyrics.to_csv('lyrics_analysis.csv', encoding='utf-8')
